# %%
import pandas as pd 
import numpy as np

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, length
from pyspark.sql.functions import explode, avg
import re
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
# Out:
# /opt/conda/lib/python3.7/site-packages/pyspark/bin/load-spark-env.sh: line 68: ps: command not found
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/28 14:50:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Set the option to display all columns
pd.set_option('display.max_columns', None)

# %%
#path = "/Users/acgid/Downloads/nba_stats/"
#Individual Statistics
file_1 = "Player Award Shares.csv" #Truth data and dependent variable
file_2 = "Player Totals.csv"
file_3 = "Player Per Game.csv"
file_4 = "Player Play By Play.csv"
file_5 = "Player Shooting.csv"
#Advanced Individual Statistics
file_6 = "Advanced.csv"
file_7 = "Per 36 Minutes.csv"
file_8 = "Per 100 Poss.csv"
#Teams Info & Stats
file_9 = "Team Totals.csv"
file_10 = "Team Stats Per Game.csv"
file_11 = "Team Stats Per 100 Poss.csv"
file_12 = "Opponent Stats Per Game.csv"
file_13 = "Opponent Stats Per 100 Poss.csv"

# %%
award_df = spark.read.csv(file_1, header=True, inferSchema=True)
plyr_tot_df = spark.read.csv(file_2, header=True, inferSchema=True)
ppg_df = spark.read.csv(file_3, header=True, inferSchema=True)
plyr_pbp_df = spark.read.csv(file_4, header=True, inferSchema=True)
plyr_shtg_df = spark.read.csv(file_5, header=True, inferSchema=True)
adv_df = spark.read.csv(file_6, header=True, inferSchema=True)
plyr_p36min_df = spark.read.csv(file_7, header=True, inferSchema=True)
plyr_p100ps_df = spark.read.csv(file_8, header=True, inferSchema=True)
tm_tot_df = spark.read.csv(file_9, header=True, inferSchema=True)
tm_pg_df = spark.read.csv(file_10, header=True, inferSchema=True)
tm_p100ps_df = spark.read.csv(file_11, header=True, inferSchema=True)
op_pg_df = spark.read.csv(file_12, header=True, inferSchema=True)
op_p100ps_df = spark.read.csv(file_13, header=True, inferSchema=True)

# %%
# filter for 1980 or higher
award_df_filtered = award_df.filter(award_df.season >= 1980)
print("This is award_df_filtered after filter:",award_df_filtered.count())

plyr_tot_df_filtered = plyr_tot_df.filter(plyr_tot_df.season >= 1980)
print("This is plyr_tot_df_filtered after filter:", plyr_tot_df_filtered.count())

ppg_df_filtered = ppg_df.filter(ppg_df.season >= 1980)
print("This is ppg_df_filtered after filter:", ppg_df_filtered.count())

plyr_pbp_df_filtered = plyr_pbp_df.filter(plyr_pbp_df.season >= 1980)
print("This is plyr_pbp_df_filtered after filter:", plyr_pbp_df_filtered.count())

plyr_shtg_df_filtered = plyr_shtg_df.filter(plyr_shtg_df.season >= 1980)
print("This is plyr_shtg_df_filtered after filter:", plyr_shtg_df_filtered.count())

adv_df_filtered = adv_df.filter(adv_df.season >= 1980)
print("This is adv_df_filtered after filter:", adv_df_filtered.count())

plyr_p36min_df_filtered = plyr_p36min_df.filter(plyr_p36min_df.season >= 1980)
print("This is plyr_p36min_df_filtered after filter:", plyr_p36min_df_filtered.count())

plyr_p100ps_df_filtered = plyr_p100ps_df.filter(plyr_p100ps_df.season >= 1980)
print("This is plyr_p100ps_df_filtered after filter:", plyr_p100ps_df_filtered.count())

tm_tot_df_filtered = tm_tot_df.filter(tm_tot_df.season >= 1980)
print("This is tm_tot_df_filtered after filter:", tm_tot_df_filtered.count())

tm_pg_df_filtered = tm_pg_df.filter(tm_pg_df.season >= 1980)
print("This is tm_pg_df_filtered after filter:", tm_pg_df_filtered.count())

tm_p100ps_df_filtered = tm_p100ps_df.filter(tm_p100ps_df.season >= 1980)
print("This is tm_p100ps_df_filtered after filter:", tm_p100ps_df_filtered.count())

op_pg_df_filtered = op_pg_df.filter(op_pg_df.season >= 1980)
print("This is op_pg_df_filtered after filter:", op_pg_df_filtered.count())

op_p100ps_df_filtered = op_p100ps_df.filter(op_p100ps_df.season >= 1980)
print("This is op_p100ps_df_filtered after filter:",op_p100ps_df_filtered.count())
# Out:
# This is award_df_filtered after filter: 2897
# This is plyr_tot_df_filtered after filter: 24616
# This is ppg_df_filtered after filter: 24616
# This is plyr_pbp_df_filtered after filter: 17521
# This is plyr_shtg_df_filtered after filter: 17521
# This is adv_df_filtered after filter: 24616
# This is plyr_p36min_df_filtered after filter: 24616
# This is plyr_p100ps_df_filtered after filter: 24616
# This is tm_tot_df_filtered after filter: 1330
# This is tm_pg_df_filtered after filter: 1330
# This is tm_p100ps_df_filtered after filter: 1284
# This is op_pg_df_filtered after filter: 1330
# This is op_p100ps_df_filtered after filter: 1284

# %%
award_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('award', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'int'),
#  ('first', 'string'),
#  ('pts_won', 'string'),
#  ('pts_max', 'string'),
#  ('share', 'string'),
#  ('winner', 'boolean')]

# %%
plyr_tot_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'string'),
#  ('fg', 'int'),
#  ('fga', 'int'),
#  ('fg_percent', 'string'),
#  ('x3p', 'string'),
#  ('x3pa', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p', 'string'),
#  ('x2pa', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft', 'int'),
#  ('fta', 'int'),
#  ('ft_percent', 'string'),
#  ('orb', 'string'),
#  ('drb', 'string'),
#  ('trb', 'string'),
#  ('ast', 'int'),
#  ('stl', 'string'),
#  ('blk', 'string'),
#  ('tov', 'string'),
#  ('pf', 'string'),
#  ('pts', 'int'),
#  ('trp_dbl', 'string')]

# %%
ppg_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp_per_game', 'string'),
#  ('fg_per_game', 'double'),
#  ('fga_per_game', 'double'),
#  ('fg_percent', 'string'),
#  ('x3p_per_game', 'string'),
#  ('x3pa_per_game', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_game', 'string'),
#  ('x2pa_per_game', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_game', 'double'),
#  ('fta_per_game', 'double'),
#  ('ft_percent', 'string'),
#  ('orb_per_game', 'string'),
#  ('drb_per_game', 'string'),
#  ('trb_per_game', 'string'),
#  ('ast_per_game', 'double'),
#  ('stl_per_game', 'string'),
#  ('blk_per_game', 'string'),
#  ('tov_per_game', 'string'),
#  ('pf_per_game', 'string'),
#  ('pts_per_game', 'double')]

# %%
plyr_pbp_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'int'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'int'),
#  ('mp', 'int'),
#  ('pg_percent', 'string'),
#  ('sg_percent', 'string'),
#  ('sf_percent', 'string'),
#  ('pf_percent', 'string'),
#  ('c_percent', 'string'),
#  ('on_court_plus_minus_per_100_poss', 'string'),
#  ('net_plus_minus_per_100_poss', 'string'),
#  ('bad_pass_turnover', 'int'),
#  ('lost_ball_turnover', 'int'),
#  ('shooting_foul_committed', 'int'),
#  ('offensive_foul_committed', 'int'),
#  ('shooting_foul_drawn', 'int'),
#  ('offensive_foul_drawn', 'string'),
#  ('points_generated_by_assists', 'int'),
#  ('and1', 'int'),
#  ('fga_blocked', 'int')]

# %%
plyr_shtg_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'int'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'int'),
#  ('mp', 'int'),
#  ('fg_percent', 'string'),
#  ('avg_dist_fga', 'string'),
#  ('percent_fga_from_x2p_range', 'string'),
#  ('percent_fga_from_x0_3_range', 'string'),
#  ('percent_fga_from_x3_10_range', 'string'),
#  ('percent_fga_from_x10_16_range', 'string'),
#  ('percent_fga_from_x16_3p_range', 'string'),
#  ('percent_fga_from_x3p_range', 'string'),
#  ('fg_percent_from_x2p_range', 'string'),
#  ('fg_percent_from_x0_3_range', 'string'),
#  ('fg_percent_from_x3_10_range', 'string'),
#  ('fg_percent_from_x10_16_range', 'string'),
#  ('fg_percent_from_x16_3p_range', 'string'),
#  ('fg_percent_from_x3p_range', 'string'),
#  ('percent_assisted_x2p_fg', 'string'),
#  ('percent_assisted_x3p_fg', 'string'),
#  ('percent_dunks_of_fga', 'string'),
#  ('num_of_dunks', 'int'),
#  ('percent_corner_3s_of_3pa', 'string'),
#  ('corner_3_point_percent', 'string'),
#  ('num_heaves_attempted', 'int'),
#  ('num_heaves_made', 'int')]

# %%
adv_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'string'),
#  ('per', 'string'),
#  ('ts_percent', 'string'),
#  ('x3p_ar', 'string'),
#  ('f_tr', 'string'),
#  ('orb_percent', 'string'),
#  ('drb_percent', 'string'),
#  ('trb_percent', 'string'),
#  ('ast_percent', 'string'),
#  ('stl_percent', 'string'),
#  ('blk_percent', 'string'),
#  ('tov_percent', 'string'),
#  ('usg_percent', 'string'),
#  ('ows', 'string'),
#  ('dws', 'string'),
#  ('ws', 'string'),
#  ('ws_48', 'string'),
#  ('obpm', 'string'),
#  ('dbpm', 'string'),
#  ('bpm', 'string'),
#  ('vorp', 'string')]

# %%
plyr_p36min_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'int'),
#  ('fg_per_36_min', 'string'),
#  ('fga_per_36_min', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_36_min', 'string'),
#  ('x3pa_per_36_min', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_36_min', 'string'),
#  ('x2pa_per_36_min', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_36_min', 'string'),
#  ('fta_per_36_min', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_36_min', 'string'),
#  ('drb_per_36_min', 'string'),
#  ('trb_per_36_min', 'string'),
#  ('ast_per_36_min', 'string'),
#  ('stl_per_36_min', 'string'),
#  ('blk_per_36_min', 'string'),
#  ('tov_per_36_min', 'string'),
#  ('pf_per_36_min', 'string'),
#  ('pts_per_36_min', 'string')]

# %%
plyr_p100ps_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'int'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'int'),
#  ('fg_per_100_poss', 'string'),
#  ('fga_per_100_poss', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_100_poss', 'string'),
#  ('x3pa_per_100_poss', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_100_poss', 'string'),
#  ('x2pa_per_100_poss', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_100_poss', 'string'),
#  ('fta_per_100_poss', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_100_poss', 'string'),
#  ('drb_per_100_poss', 'string'),
#  ('trb_per_100_poss', 'string'),
#  ('ast_per_100_poss', 'string'),
#  ('stl_per_100_poss', 'string'),
#  ('blk_per_100_poss', 'string'),
#  ('tov_per_100_poss', 'string'),
#  ('pf_per_100_poss', 'string'),
#  ('pts_per_100_poss', 'string'),
#  ('o_rtg', 'string'),
#  ('d_rtg', 'string')]

# %%
tm_tot_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'string'),
#  ('mp', 'string'),
#  ('fg', 'string'),
#  ('fga', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p', 'string'),
#  ('x3pa', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p', 'string'),
#  ('x2pa', 'string'),
#  ('x2p_percent', 'string'),
#  ('ft', 'string'),
#  ('fta', 'string'),
#  ('ft_percent', 'string'),
#  ('orb', 'string'),
#  ('drb', 'string'),
#  ('trb', 'string'),
#  ('ast', 'string'),
#  ('stl', 'string'),
#  ('blk', 'string'),
#  ('tov', 'string'),
#  ('pf', 'string'),
#  ('pts', 'string')]

# %%
tm_pg_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'string'),
#  ('mp_per_game', 'string'),
#  ('fg_per_game', 'string'),
#  ('fga_per_game', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_game', 'string'),
#  ('x3pa_per_game', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_game', 'string'),
#  ('x2pa_per_game', 'string'),
#  ('x2p_percent', 'string'),
#  ('ft_per_game', 'string'),
#  ('fta_per_game', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_game', 'string'),
#  ('drb_per_game', 'string'),
#  ('trb_per_game', 'string'),
#  ('ast_per_game', 'string'),
#  ('stl_per_game', 'string'),
#  ('blk_per_game', 'string'),
#  ('tov_per_game', 'string'),
#  ('pf_per_game', 'string'),
#  ('pts_per_game', 'string')]

# %%
op_pg_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'string'),
#  ('mp_per_game', 'string'),
#  ('opp_fg_per_game', 'string'),
#  ('opp_fga_per_game', 'string'),
#  ('opp_fg_percent', 'string'),
#  ('opp_x3p_per_game', 'string'),
#  ('opp_x3pa_per_game', 'string'),
#  ('opp_x3p_percent', 'string'),
#  ('opp_x2p_per_game', 'string'),
#  ('opp_x2pa_per_game', 'string'),
#  ('opp_x2p_percent', 'string'),
#  ('opp_ft_per_game', 'string'),
#  ('opp_fta_per_game', 'string'),
#  ('opp_ft_percent', 'string'),
#  ('opp_orb_per_game', 'string'),
#  ('opp_drb_per_game', 'string'),
#  ('opp_trb_per_game', 'string'),
#  ('opp_ast_per_game', 'string'),
#  ('opp_stl_per_game', 'string'),
#  ('opp_blk_per_game', 'string'),
#  ('opp_tov_per_game', 'string'),
#  ('opp_pf_per_game', 'string'),
#  ('opp_pts_per_game', 'string')]

# %%
tm_p100ps_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'int'),
#  ('mp', 'int'),
#  ('fg_per_100_poss', 'double'),
#  ('fga_per_100_poss', 'double'),
#  ('fg_percent', 'double'),
#  ('x3p_per_100_poss', 'string'),
#  ('x3pa_per_100_poss', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_100_poss', 'double'),
#  ('x2pa_per_100_poss', 'double'),
#  ('x2p_percent', 'double'),
#  ('ft_per_100_poss', 'double'),
#  ('fta_per_100_poss', 'double'),
#  ('ft_percent', 'double'),
#  ('orb_per_100_poss', 'double'),
#  ('drb_per_100_poss', 'double'),
#  ('trb_per_100_poss', 'double'),
#  ('ast_per_100_poss', 'double'),
#  ('stl_per_100_poss', 'double'),
#  ('blk_per_100_poss', 'double'),
#  ('tov_per_100_poss', 'double'),
#  ('pf_per_100_poss', 'double'),
#  ('pts_per_100_poss', 'double')]

# %%
op_p100ps_df_filtered.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'int'),
#  ('mp', 'int'),
#  ('opp_fg_per_100_poss', 'double'),
#  ('opp_fga_per_100_poss', 'double'),
#  ('opp_fg_percent', 'double'),
#  ('opp_x3p_per_100_poss', 'string'),
#  ('opp_x3pa_per_100_poss', 'string'),
#  ('opp_x3p_percent', 'string'),
#  ('opp_x2p_per_100_poss', 'double'),
#  ('opp_x2pa_per_100_poss', 'double'),
#  ('opp_x2p_percent', 'double'),
#  ('opp_ft_per_100_poss', 'double'),
#  ('opp_fta_per_100_poss', 'double'),
#  ('opp_ft_percent', 'double'),
#  ('opp_orb_per_100_poss', 'double'),
#  ('opp_drb_per_100_poss', 'double'),
#  ('opp_trb_per_100_poss', 'double'),
#  ('opp_ast_per_100_poss', 'double'),
#  ('opp_stl_per_100_poss', 'double'),
#  ('opp_blk_per_100_poss', 'double'),
#  ('opp_tov_per_100_poss', 'double'),
#  ('opp_pf_per_100_poss', 'double'),
#  ('opp_pts_per_100_poss', 'double')]

# %%
temp1 = plyr_tot_df_filtered.join(ppg_df_filtered, 
                                  on=["season","lg","player", "player_id", "age", "team", "pos","g","gs"], 
                                  how="left")
print("this is after merge:",temp1.count())
# Out:
# this is after merge: 24616

# %%
temp1.show()
# Out:
# 25/09/28 14:50:58 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------+---+--------------------+---------+---+----+---+---+---+----+---+----+----------+---+----+-----------+---+----+-----------+------------+---+---+----------+---+---+---+---+---+---+---+---+----+-------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+------------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+
# |season| lg|              player|player_id|age|team|pos|  g| gs|  mp| fg| fga|fg_percent|x3p|x3pa|x3p_percent|x2p|x2pa|x2p_percent|e_fg_percent| ft|fta|ft_percent|orb|drb|trb|ast|stl|blk|tov| pf| pts|trp_dbl|mp_per_game|fg_per_game|fga_per_game|fg_percent|x3p_per_game|x3pa_per_game|x3p_percent|x2p_per_game|x2pa_per_game|x2p_percent|e_fg_percent|ft_per_game|fta_per_game|ft_percent|orb_per_game|drb_per_game|trb_per_game|ast_per_game|stl_per_game|blk_per_game|tov_per_game|pf_per_game|pts_per_game|
# +------+---+--------------------+---------+---+----+---+---+---+----+---+----+----------+---+----+-----------+---+----+-----------+------------+---+---+----------+---+---+---+---+---+---+---+---+----+-------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+------------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+
# |  2025|NBA|    Precious Achiuwa|achiupr01| 25| NYK|  C| 57| 10|1170|164| 327|     0.502| 10|  36|      0.278|154| 291|      0.529|       0.517| 41| 69|     0.594|101|216|317| 55| 47| 42| 45| 81| 379|      0|       20.5|        2.9|         5.7|     0.502|         0.2|          0.6|      0.278|         2.7|          5.1|      0.529|       0.517|        0.7|         1.2|     0.594|         1.8|         3.8|         5.6|         1.0|         0.8|         0.7|         0.8|        1.4|         6.6|
# |  2025|NBA|        Steven Adams|adamsst01| 31| HOU|  C| 58|  3| 794| 91| 167|     0.545|  0|   2|          0| 91| 165|      0.552|       0.545| 43| 93|     0.462|166|161|327| 66| 22| 28| 54| 60| 225|      0|       13.7|        1.6|         2.9|     0.545|           0|            0|          0|         1.6|          2.8|      0.552|       0.545|        0.7|         1.6|     0.462|         2.9|         2.8|         5.6|         1.1|         0.4|         0.5|         0.9|          1|         3.9|
# |  2025|NBA|          OG Anunoby|anunoog01| 27| NYK| PF| 74| 74|2706|489|1027|     0.476|171| 460|      0.372|318| 567|      0.561|       0.559|183|226|      0.81| 97|261|358|164|110| 65|102|172|1332|      0|       36.6|        6.6|        13.9|     0.476|         2.3|          6.2|      0.372|         4.3|          7.7|      0.561|       0.559|        2.5|         3.1|      0.81|         1.3|         3.5|         4.8|         2.2|         1.5|         0.9|         1.4|        2.3|        18.0|
# |  2025|NBA|        Armel Traoré|armeltr01| 22| LAL| SF|  9|  0|  67|  6|  19|     0.316|  0|   7|          0|  6|  12|        0.5|       0.316|  2|  7|     0.286|  2| 13| 15|  1|  4|  2|  3|  6|  14|      0|        7.4|        0.7|         2.1|     0.316|           0|          0.8|          0|         0.7|          1.3|        0.5|       0.316|        0.2|         0.8|     0.286|         0.2|         1.4|         1.7|         0.1|         0.4|         0.2|         0.3|        0.7|         1.6|
# |  2025|NBA|         Deni Avdija|avdijde01| 24| POR| SF| 72| 54|2161|402| 844|     0.476|125| 342|      0.365|277| 502|      0.552|        0.55|290|372|      0.78|110|412|522|281| 71| 35|196|171|1219|      2|         30|        5.6|        11.7|     0.476|         1.7|          4.8|      0.365|         3.8|            7|      0.552|        0.55|        4.0|         5.2|      0.78|         1.5|         5.7|         7.3|         3.9|           1|         0.5|         2.7|        2.4|        16.9|
# |  2025|NBA|       Deandre Ayton|aytonde01| 26| POR|  C| 40| 40|1206|265| 468|     0.566|  6|  32|      0.188|259| 436|      0.594|       0.573| 40| 60|     0.667|124|282|406| 64| 31| 39| 69| 88| 576|      0|       30.2|        6.6|        11.7|     0.566|         0.2|          0.8|      0.188|         6.5|         10.9|      0.594|       0.573|        1.0|         1.5|     0.667|         3.1|         7.1|        10.2|         1.6|         0.8|           1|         1.7|        2.2|        14.4|
# |  2025|NBA|   Marvin Bagley III|baglema01| 25| 2TM| PF| 31|  2| 265| 55| 106|     0.519|  3|  19|      0.158| 52|  87|      0.598|       0.533| 23| 35|     0.657| 38| 46| 84| 11|  9|  8| 12| 18| 136|      0|        8.5|        1.8|         3.4|     0.519|         0.1|          0.6|      0.158|         1.7|          2.8|      0.598|       0.533|        0.7|         1.1|     0.657|         1.2|         1.5|         2.7|         0.4|         0.3|         0.3|         0.4|        0.6|         4.4|
# +------+---+--------------------+---------+---+----+---+---+---+----+---+----+----------+---+----+-----------+---+----+-----------+------------+---+---+----------+---+---+---+---+---+---+---+---+----+-------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+------------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+
# only showing top 20 rows

# %%
temp1.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'string'),
#  ('fg', 'int'),
#  ('fga', 'int'),
#  ('fg_percent', 'string'),
#  ('x3p', 'string'),
#  ('x3pa', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p', 'string'),
#  ('x2pa', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft', 'int'),
#  ('fta', 'int'),
#  ('ft_percent', 'string'),
#  ('orb', 'string'),
#  ('drb', 'string'),
#  ('trb', 'string'),
#  ('ast', 'int'),
#  ('stl', 'string'),
#  ('blk', 'string'),
#  ('tov', 'string'),
#  ('pf', 'string'),
#  ('pts', 'int'),
#  ('trp_dbl', 'string'),
#  ('mp_per_game', 'string'),
#  ('fg_per_game', 'double'),
#  ('fga_per_game', 'double'),
#  ('fg_percent', 'string'),
#  ('x3p_per_game', 'string'),
#  ('x3pa_per_game', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_game', 'string'),
#  ('x2pa_per_game', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_game', 'double'),
#  ('fta_per_game', 'double'),
#  ('ft_percent', 'string'),
#  ('orb_per_game', 'string'),
#  ('drb_per_game', 'string'),
#  ('trb_per_game', 'string'),
#  ('ast_per_game', 'double'),
#  ('stl_per_game', 'string'),
#  ('blk_per_game', 'string'),
#  ('tov_per_game', 'string'),
#  ('pf_per_game', 'string'),
#  ('pts_per_game', 'double')]

# %%
temp2 = plyr_pbp_df_filtered.join(plyr_shtg_df_filtered, 
                                  on=["season","lg","player", "player_id", "age", "team", "pos","g","gs","mp"], 
                                  how="left")

print("this is after merge:",temp2.count())
# Out:
# this is after merge: 17521

# %%
temp2.show()
# Out:
# +------+---+--------------------+---------+---+----+---+---+---+----+----------+----------+----------+----------+---------+--------------------------------+---------------------------+-----------------+------------------+-----------------------+------------------------+-------------------+--------------------+---------------------------+----+-----------+----------+------------+--------------------------+---------------------------+----------------------------+-----------------------------+-----------------------------+--------------------------+-------------------------+--------------------------+---------------------------+----------------------------+----------------------------+-------------------------+-----------------------+-----------------------+--------------------+------------+------------------------+----------------------+--------------------+---------------+
# |season| lg|              player|player_id|age|team|pos|  g| gs|  mp|pg_percent|sg_percent|sf_percent|pf_percent|c_percent|on_court_plus_minus_per_100_poss|net_plus_minus_per_100_poss|bad_pass_turnover|lost_ball_turnover|shooting_foul_committed|offensive_foul_committed|shooting_foul_drawn|offensive_foul_drawn|points_generated_by_assists|and1|fga_blocked|fg_percent|avg_dist_fga|percent_fga_from_x2p_range|percent_fga_from_x0_3_range|percent_fga_from_x3_10_range|percent_fga_from_x10_16_range|percent_fga_from_x16_3p_range|percent_fga_from_x3p_range|fg_percent_from_x2p_range|fg_percent_from_x0_3_range|fg_percent_from_x3_10_range|fg_percent_from_x10_16_range|fg_percent_from_x16_3p_range|fg_percent_from_x3p_range|percent_assisted_x2p_fg|percent_assisted_x3p_fg|percent_dunks_of_fga|num_of_dunks|percent_corner_3s_of_3pa|corner_3_point_percent|num_heaves_attempted|num_heaves_made|
# +------+---+--------------------+---------+---+----+---+---+---+----+----------+----------+----------+----------+---------+--------------------------------+---------------------------+-----------------+------------------+-----------------------+------------------------+-------------------+--------------------+---------------------------+----+-----------+----------+------------+--------------------------+---------------------------+----------------------------+-----------------------------+-----------------------------+--------------------------+-------------------------+--------------------------+---------------------------+----------------------------+----------------------------+-------------------------+-----------------------+-----------------------+--------------------+------------+------------------------+----------------------+--------------------+---------------+
# only showing top 20 rows

# %%
temp2.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'int'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'int'),
#  ('mp', 'int'),
#  ('pg_percent', 'string'),
#  ('sg_percent', 'string'),
#  ('sf_percent', 'string'),
#  ('pf_percent', 'string'),
#  ('c_percent', 'string'),
#  ('on_court_plus_minus_per_100_poss', 'string'),
#  ('net_plus_minus_per_100_poss', 'string'),
#  ('bad_pass_turnover', 'int'),
#  ('lost_ball_turnover', 'int'),
#  ('shooting_foul_committed', 'int'),
#  ('offensive_foul_committed', 'int'),
#  ('shooting_foul_drawn', 'int'),
#  ('offensive_foul_drawn', 'string'),
#  ('points_generated_by_assists', 'int'),
#  ('and1', 'int'),
#  ('fga_blocked', 'int'),
#  ('fg_percent', 'string'),
#  ('avg_dist_fga', 'string'),
#  ('percent_fga_from_x2p_range', 'string'),
#  ('percent_fga_from_x0_3_range', 'string'),
#  ('percent_fga_from_x3_10_range', 'string'),
#  ('percent_fga_from_x10_16_range', 'string'),
#  ('percent_fga_from_x16_3p_range', 'string'),
#  ('percent_fga_from_x3p_range', 'string'),
#  ('fg_percent_from_x2p_range', 'string'),
#  ('fg_percent_from_x0_3_range', 'string'),
#  ('fg_percent_from_x3_10_range', 'string'),
#  ('fg_percent_from_x10_16_range', 'string'),
#  ('fg_percent_from_x16_3p_range', 'string'),
#  ('fg_percent_from_x3p_range', 'string'),
#  ('percent_assisted_x2p_fg', 'string'),
#  ('percent_assisted_x3p_fg', 'string'),
#  ('percent_dunks_of_fga', 'string'),
#  ('num_of_dunks', 'int'),
#  ('percent_corner_3s_of_3pa', 'string'),
#  ('corner_3_point_percent', 'string'),
#  ('num_heaves_attempted', 'int'),
#  ('num_heaves_made', 'int')]

# %%
temp3_a = adv_df_filtered.join(plyr_p36min_df_filtered, 
                                  on=["season","lg","player", "player_id", "age", "team", "pos","g","gs","mp"], 
                                  how="left")

temp3 = temp3_a.join(plyr_p100ps_df_filtered, 
                                  on=["season","lg","player", "player_id", "age", "team", "pos","g","gs","mp"], 
                                  how="left")


print("this is after merge:",temp3.count())
# Out:
# this is after merge: 24616

# %%
temp3.show()
# Out:
# +------+---+--------------------+---------+---+----+---+---+---+----+----+----------+------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----+---+----+------+----+----+----+----+-------------+--------------+----------+--------------+---------------+-----------+--------------+---------------+-----------+------------+-------------+--------------+----------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------+--------------+---------------+----------------+----------+----------------+-----------------+-----------+----------------+-----------------+-----------+------------+---------------+----------------+----------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+-----+-----+
# |season| lg|              player|player_id|age|team|pos|  g| gs|  mp| per|ts_percent|x3p_ar| f_tr|orb_percent|drb_percent|trb_percent|ast_percent|stl_percent|blk_percent|tov_percent|usg_percent| ows|dws|  ws| ws_48|obpm|dbpm| bpm|vorp|fg_per_36_min|fga_per_36_min|fg_percent|x3p_per_36_min|x3pa_per_36_min|x3p_percent|x2p_per_36_min|x2pa_per_36_min|x2p_percent|e_fg_percent|ft_per_36_min|fta_per_36_min|ft_percent|orb_per_36_min|drb_per_36_min|trb_per_36_min|ast_per_36_min|stl_per_36_min|blk_per_36_min|tov_per_36_min|pf_per_36_min|pts_per_36_min|fg_per_100_poss|fga_per_100_poss|fg_percent|x3p_per_100_poss|x3pa_per_100_poss|x3p_percent|x2p_per_100_poss|x2pa_per_100_poss|x2p_percent|e_fg_percent|ft_per_100_poss|fta_per_100_poss|ft_percent|orb_per_100_poss|drb_per_100_poss|trb_per_100_poss|ast_per_100_poss|stl_per_100_poss|blk_per_100_poss|tov_per_100_poss|pf_per_100_poss|pts_per_100_poss|o_rtg|d_rtg|
# +------+---+--------------------+---------+---+----+---+---+---+----+----+----------+------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----+---+----+------+----+----+----+----+-------------+--------------+----------+--------------+---------------+-----------+--------------+---------------+-----------+------------+-------------+--------------+----------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------+--------------+---------------+----------------+----------+----------------+-----------------+-----------+----------------+-----------------+-----------+------------+---------------+----------------+----------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+-----+-----+
# |  2025|NBA|    Precious Achiuwa|achiupr01| 25| NYK|  C| 57| 10|1170|13.6|      0.53|  0.11|0.211|         10|         21|       15.5|        6.2|          2|        3.3|       11.2|       14.9| 0.7|1.7| 2.3| 0.095|-2.1| 0.2|-1.9|   0|            5|          10.1|     0.502|           0.3|            1.1|      0.278|           4.7|              9|      0.529|       0.517|          1.3|           2.1|     0.594|           3.1|           6.6|           9.8|           1.7|           1.4|           1.3|           1.4|          2.5|          11.7|              7|            13.9|     0.502|             0.4|              1.5|      0.278|             6.5|             12.3|      0.529|       0.517|            1.7|             2.9|     0.594|             4.3|             9.2|            13.4|             2.3|               2|             1.8|             1.9|            3.4|            16.1|  112|  111|
# |  2025|NBA|        Steven Adams|adamsst01| 31| HOU|  C| 58|  3| 794|16.6|     0.541| 0.012|0.557|       21.8|         22|       21.9|       10.9|        1.3|        3.2|       20.6|       13.6|   1|1.3| 2.3| 0.137|   0| 0.3| 0.3| 0.5|          4.1|           7.6|     0.545|             0|            0.1|          0|           4.1|            7.5|      0.552|       0.545|          1.9|           4.2|     0.462|           7.5|           7.3|          14.8|             3|             1|           1.3|           2.4|          2.7|          10.2|            5.6|            10.2|     0.545|               0|              0.1|          0|             5.6|             10.1|      0.552|       0.545|            2.6|             5.7|     0.462|            10.2|             9.9|              20|               4|             1.3|             1.7|             3.3|            3.7|            13.8|  118|  109|
# |  2025|NBA|   Marvin Bagley III|baglema01| 25| 2TM| PF| 31|  2| 265|18.4|      0.56| 0.179| 0.33|         15|       18.2|       16.6|        6.5|        1.6|        2.7|          9|       20.9| 0.4|0.2| 0.6| 0.108| 0.4|-1.6|-1.2| 0.1|          7.5|          14.4|     0.519|           0.4|            2.6|      0.158|           7.1|           11.8|      0.598|       0.533|          3.1|           4.8|     0.657|           5.2|           6.2|          11.4|           1.5|           1.2|           1.1|           1.6|          2.4|          18.5|            9.8|            18.9|     0.519|             0.5|              3.4|      0.158|             9.3|             15.5|      0.598|       0.533|            4.1|             6.2|     0.657|             6.8|             8.2|            14.9|               2|             1.6|             1.4|             2.1|            3.2|            24.2|  117|  115|
# +------+---+--------------------+---------+---+----+---+---+---+----+----+----------+------+-----+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+----+---+----+------+----+----+----+----+-------------+--------------+----------+--------------+---------------+-----------+--------------+---------------+-----------+------------+-------------+--------------+----------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+-------------+--------------+---------------+----------------+----------+----------------+-----------------+-----------+----------------+-----------------+-----------+------------+---------------+----------------+----------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+-----+-----+
# only showing top 20 rows

# %%
temp3.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('player', 'string'),
#  ('player_id', 'string'),
#  ('age', 'string'),
#  ('team', 'string'),
#  ('pos', 'string'),
#  ('g', 'int'),
#  ('gs', 'string'),
#  ('mp', 'string'),
#  ('per', 'string'),
#  ('ts_percent', 'string'),
#  ('x3p_ar', 'string'),
#  ('f_tr', 'string'),
#  ('orb_percent', 'string'),
#  ('drb_percent', 'string'),
#  ('trb_percent', 'string'),
#  ('ast_percent', 'string'),
#  ('stl_percent', 'string'),
#  ('blk_percent', 'string'),
#  ('tov_percent', 'string'),
#  ('usg_percent', 'string'),
#  ('ows', 'string'),
#  ('dws', 'string'),
#  ('ws', 'string'),
#  ('ws_48', 'string'),
#  ('obpm', 'string'),
#  ('dbpm', 'string'),
#  ('bpm', 'string'),
#  ('vorp', 'string'),
#  ('fg_per_36_min', 'string'),
#  ('fga_per_36_min', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_36_min', 'string'),
#  ('x3pa_per_36_min', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_36_min', 'string'),
#  ('x2pa_per_36_min', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_36_min', 'string'),
#  ('fta_per_36_min', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_36_min', 'string'),
#  ('drb_per_36_min', 'string'),
#  ('trb_per_36_min', 'string'),
#  ('ast_per_36_min', 'string'),
#  ('stl_per_36_min', 'string'),
#  ('blk_per_36_min', 'string'),
#  ('tov_per_36_min', 'string'),
#  ('pf_per_36_min', 'string'),
#  ('pts_per_36_min', 'string'),
#  ('fg_per_100_poss', 'string'),
#  ('fga_per_100_poss', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_100_poss', 'string'),
#  ('x3pa_per_100_poss', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_100_poss', 'string'),
#  ('x2pa_per_100_poss', 'string'),
#  ('x2p_percent', 'string'),
#  ('e_fg_percent', 'string'),
#  ('ft_per_100_poss', 'string'),
#  ('fta_per_100_poss', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_100_poss', 'string'),
#  ('drb_per_100_poss', 'string'),
#  ('trb_per_100_poss', 'string'),
#  ('ast_per_100_poss', 'string'),
#  ('stl_per_100_poss', 'string'),
#  ('blk_per_100_poss', 'string'),
#  ('tov_per_100_poss', 'string'),
#  ('pf_per_100_poss', 'string'),
#  ('pts_per_100_poss', 'string'),
#  ('o_rtg', 'string'),
#  ('d_rtg', 'string')]

# %%
temp4_a = tm_tot_df_filtered.join(tm_pg_df_filtered, 
                         on=["season","lg","team", "playoffs", "g"], 
                         how="left")

temp4 = temp4_a.join(op_pg_df_filtered, 
                         on=["season","lg","team", "playoffs", "g"], 
                         how="left")


print("this is after merge:",temp4.count())
# Out:
# this is after merge: 1330

# %%
temp4.show()
# Out:
# +------+---+--------------------+--------+---+------------+-----+----+----+----------+----+----+-----------+----+----+-----------+----+----+----------+----+----+----+----+---+---+----+----+----+------------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+------------+-----------+---------------+----------------+--------------+----------------+-----------------+---------------+----------------+-----------------+---------------+---------------+----------------+--------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+
# |season| lg|                team|playoffs|  g|abbreviation|   mp|  fg| fga|fg_percent| x3p|x3pa|x3p_percent| x2p|x2pa|x2p_percent|  ft| fta|ft_percent| orb| drb| trb| ast|stl|blk| tov|  pf| pts|abbreviation|mp_per_game|fg_per_game|fga_per_game|fg_percent|x3p_per_game|x3pa_per_game|x3p_percent|x2p_per_game|x2pa_per_game|x2p_percent|ft_per_game|fta_per_game|ft_percent|orb_per_game|drb_per_game|trb_per_game|ast_per_game|stl_per_game|blk_per_game|tov_per_game|pf_per_game|pts_per_game|abbreviation|mp_per_game|opp_fg_per_game|opp_fga_per_game|opp_fg_percent|opp_x3p_per_game|opp_x3pa_per_game|opp_x3p_percent|opp_x2p_per_game|opp_x2pa_per_game|opp_x2p_percent|opp_ft_per_game|opp_fta_per_game|opp_ft_percent|opp_orb_per_game|opp_drb_per_game|opp_trb_per_game|opp_ast_per_game|opp_stl_per_game|opp_blk_per_game|opp_tov_per_game|opp_pf_per_game|opp_pts_per_game|
# +------+---+--------------------+--------+---+------------+-----+----+----+----------+----+----+-----------+----+----+-----------+----+----+----------+----+----+----+----+---+---+----+----+----+------------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+------------+-----------+---------------+----------------+--------------+----------------+-----------------+---------------+----------------+-----------------+---------------+---------------+----------------+--------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+
# |  2025|NBA|       Atlanta Hawks|    true| 82|         ATL|19780|3556|7528|     0.472|1107|3089|      0.358|2449|4439|      0.552|1472|1900|     0.775| 974|2675|3649|2426|798|419|1273|1564|9691|         ATL|      241.2|       43.4|        91.8|     0.472|        13.5|         37.7|      0.358|        29.9|         54.1|      0.552|         18|        23.2|     0.775|        11.9|        32.6|        44.5|        29.6|         9.7|         5.1|        15.5|       19.1|       118.2|         ATL|      241.2|           43.4|            90.2|         0.481|            14.3|             37.8|          0.377|            29.2|             52.4|          0.557|           18.2|            22.7|         0.802|            10.3|            33.4|            43.7|            28.2|             9.2|             4.9|              16|           19.1|           119.3|
# |  2025|NBA|     New York Knicks|    true| 82|         NYK|19880|3553|7315|     0.486|1031|2794|      0.369|2522|4521|      0.558|1357|1696|       0.8| 890|2607|3497|2254|671|324|1088|1407|9494|         NYK|      242.4|       43.3|        89.2|     0.486|        12.6|         34.1|      0.369|        30.8|         55.1|      0.558|       16.5|        20.7|       0.8|        10.9|        31.8|        42.6|        27.5|         8.2|           4|        13.3|       17.2|       115.8|         NYK|      242.4|           41.6|            87.7|         0.474|            13.1|             35.7|          0.367|            28.5|               52|          0.548|           15.4|            19.5|         0.789|            10.9|              31|            41.8|            25.2|               7|               5|            14.5|             19|           111.7|
# +------+---+--------------------+--------+---+------------+-----+----+----+----------+----+----+-----------+----+----+-----------+----+----+----------+----+----+----+----+---+---+----+----+----+------------+-----------+-----------+------------+----------+------------+-------------+-----------+------------+-------------+-----------+-----------+------------+----------+------------+------------+------------+------------+------------+------------+------------+-----------+------------+------------+-----------+---------------+----------------+--------------+----------------+-----------------+---------------+----------------+-----------------+---------------+---------------+----------------+--------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+
# only showing top 20 rows

# %%
temp4.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'string'),
#  ('abbreviation', 'string'),
#  ('mp', 'string'),
#  ('fg', 'string'),
#  ('fga', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p', 'string'),
#  ('x3pa', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p', 'string'),
#  ('x2pa', 'string'),
#  ('x2p_percent', 'string'),
#  ('ft', 'string'),
#  ('fta', 'string'),
#  ('ft_percent', 'string'),
#  ('orb', 'string'),
#  ('drb', 'string'),
#  ('trb', 'string'),
#  ('ast', 'string'),
#  ('stl', 'string'),
#  ('blk', 'string'),
#  ('tov', 'string'),
#  ('pf', 'string'),
#  ('pts', 'string'),
#  ('abbreviation', 'string'),
#  ('mp_per_game', 'string'),
#  ('fg_per_game', 'string'),
#  ('fga_per_game', 'string'),
#  ('fg_percent', 'string'),
#  ('x3p_per_game', 'string'),
#  ('x3pa_per_game', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_game', 'string'),
#  ('x2pa_per_game', 'string'),
#  ('x2p_percent', 'string'),
#  ('ft_per_game', 'string'),
#  ('fta_per_game', 'string'),
#  ('ft_percent', 'string'),
#  ('orb_per_game', 'string'),
#  ('drb_per_game', 'string'),
#  ('trb_per_game', 'string'),
#  ('ast_per_game', 'string'),
#  ('stl_per_game', 'string'),
#  ('blk_per_game', 'string'),
#  ('tov_per_game', 'string'),
#  ('pf_per_game', 'string'),
#  ('pts_per_game', 'string'),
#  ('abbreviation', 'string'),
#  ('mp_per_game', 'string'),
#  ('opp_fg_per_game', 'string'),
#  ('opp_fga_per_game', 'string'),
#  ('opp_fg_percent', 'string'),
#  ('opp_x3p_per_game', 'string'),
#  ('opp_x3pa_per_game', 'string'),
#  ('opp_x3p_percent', 'string'),
#  ('opp_x2p_per_game', 'string'),
#  ('opp_x2pa_per_game', 'string'),
#  ('opp_x2p_percent', 'string'),
#  ('opp_ft_per_game', 'string'),
#  ('opp_fta_per_game', 'string'),
#  ('opp_ft_percent', 'string'),
#  ('opp_orb_per_game', 'string'),
#  ('opp_drb_per_game', 'string'),
#  ('opp_trb_per_game', 'string'),
#  ('opp_ast_per_game', 'string'),
#  ('opp_stl_per_game', 'string'),
#  ('opp_blk_per_game', 'string'),
#  ('opp_tov_per_game', 'string'),
#  ('opp_pf_per_game', 'string'),
#  ('opp_pts_per_game', 'string')]

# %%
temp5 = tm_p100ps_df_filtered.join(op_p100ps_df_filtered, 
                         on=["season","lg", "team", "abbreviation", "playoffs","g","mp"], 
                         how="left")

print("this is after merge:",temp5.count())
# Out:
# this is after merge: 1284

# %%
temp5.show()
# Out:
# +------+---+--------------------+------------+--------+---+-----+---------------+----------------+----------+----------------+-----------------+-----------+----------------+-----------------+-----------+---------------+----------------+----------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+-------------------+--------------------+--------------+--------------------+---------------------+---------------+--------------------+---------------------+---------------+-------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |season| lg|                team|abbreviation|playoffs|  g|   mp|fg_per_100_poss|fga_per_100_poss|fg_percent|x3p_per_100_poss|x3pa_per_100_poss|x3p_percent|x2p_per_100_poss|x2pa_per_100_poss|x2p_percent|ft_per_100_poss|fta_per_100_poss|ft_percent|orb_per_100_poss|drb_per_100_poss|trb_per_100_poss|ast_per_100_poss|stl_per_100_poss|blk_per_100_poss|tov_per_100_poss|pf_per_100_poss|pts_per_100_poss|opp_fg_per_100_poss|opp_fga_per_100_poss|opp_fg_percent|opp_x3p_per_100_poss|opp_x3pa_per_100_poss|opp_x3p_percent|opp_x2p_per_100_poss|opp_x2pa_per_100_poss|opp_x2p_percent|opp_ft_per_100_poss|opp_fta_per_100_poss|opp_ft_percent|opp_orb_per_100_poss|opp_drb_per_100_poss|opp_trb_per_100_poss|opp_ast_per_100_poss|opp_stl_per_100_poss|opp_blk_per_100_poss|opp_tov_per_100_poss|opp_pf_per_100_poss|opp_pts_per_100_poss|
# +------+---+--------------------+------------+--------+---+-----+---------------+----------------+----------+----------------+-----------------+-----------+----------------+-----------------+-----------+---------------+----------------+----------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+---------------+----------------+-------------------+--------------------+--------------+--------------------+---------------------+---------------+--------------------+---------------------+---------------+-------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |  2025|NBA|       Atlanta Hawks|         ATL|    true| 82|19780|           42.0|            89.0|     0.472|            13.1|             36.5|      0.358|            29.0|             52.5|      0.552|           17.4|            22.5|     0.775|            11.5|            31.6|            43.1|            28.7|             9.4|             5.0|            15.1|           18.5|           114.6|               42.1|                87.5|         0.481|                13.8|                 36.6|          0.377|                28.3|                 50.8|          0.557|               17.6|                22.0|         0.802|                10.0|                32.3|                42.3|                27.4|                 8.9|                 4.8|                15.5|               18.5|               115.7|
# |  2025|NBA|      Boston Celtics|         BOS|    true| 82|19830|           43.2|            93.3|     0.462|            18.4|               50|      0.368|            24.7|             43.3|      0.571|           15.8|            19.8|     0.799|            11.8|            35.2|            47.0|            27.1|             7.4|             5.7|            12.3|           16.5|           120.6|               41.8|                92.7|          0.45|                13.3|                 38.5|          0.347|                28.4|                 54.2|          0.524|               14.3|                18.3|         0.777|                11.1|                34.2|                45.3|                24.9|                 7.2|                 3.7|                13.3|               18.2|               111.1|
------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
temp5.dtypes
# Out:
# [('season', 'int'),
#  ('lg', 'string'),
#  ('team', 'string'),
#  ('abbreviation', 'string'),
#  ('playoffs', 'boolean'),
#  ('g', 'int'),
#  ('mp', 'int'),
#  ('fg_per_100_poss', 'double'),
#  ('fga_per_100_poss', 'double'),
#  ('fg_percent', 'double'),
#  ('x3p_per_100_poss', 'string'),
#  ('x3pa_per_100_poss', 'string'),
#  ('x3p_percent', 'string'),
#  ('x2p_per_100_poss', 'double'),
#  ('x2pa_per_100_poss', 'double'),
#  ('x2p_percent', 'double'),
#  ('ft_per_100_poss', 'double'),
#  ('fta_per_100_poss', 'double'),
#  ('ft_percent', 'double'),
#  ('orb_per_100_poss', 'double'),
#  ('drb_per_100_poss', 'double'),
#  ('trb_per_100_poss', 'double'),
#  ('ast_per_100_poss', 'double'),
#  ('stl_per_100_poss', 'double'),
#  ('blk_per_100_poss', 'double'),
#  ('tov_per_100_poss', 'double'),
#  ('pf_per_100_poss', 'double'),
#  ('pts_per_100_poss', 'double'),
#  ('opp_fg_per_100_poss', 'double'),
#  ('opp_fga_per_100_poss', 'double'),
#  ('opp_fg_percent', 'double'),
#  ('opp_x3p_per_100_poss', 'string'),
#  ('opp_x3pa_per_100_poss', 'string'),
#  ('opp_x3p_percent', 'string'),
#  ('opp_x2p_per_100_poss', 'double'),
#  ('opp_x2pa_per_100_poss', 'double'),
#  ('opp_x2p_percent', 'double'),
#  ('opp_ft_per_100_poss', 'double'),
#  ('opp_fta_per_100_poss', 'double'),
#  ('opp_ft_percent', 'double'),
#  ('opp_orb_per_100_poss', 'double'),
#  ('opp_drb_per_100_poss', 'double'),
#  ('opp_trb_per_100_poss', 'double'),
#  ('opp_ast_per_100_poss', 'double'),
#  ('opp_stl_per_100_poss', 'double'),
#  ('opp_blk_per_100_poss', 'double'),
#  ('opp_tov_per_100_poss', 'double'),
#  ('opp_pf_per_100_poss', 'double'),
#  ('opp_pts_per_100_poss', 'double')]

# %% [markdown]
# ## Merge for Final dataset
#
# Merge Temp1, temp2, temp3, temp4, temp5 togethere. Below is an ideas. Not decided how to go about that.

# %%
temp6_a = temp1.join(temp2,
                     on=["season","lg","player", "player_id", "age", "team", "pos","g"], 
                     how="left")
print("Join temp1 and temp 2:", temp6_a.count())

temp6_b = temp6_a.join(temp3, 
                        on=["season","lg","player", "player_id", "age", "team", "pos","g"], 
                        how="left")
print("Join temp6_a and temp3:", temp6_b.count())

temp6_c = temp6_b.join(temp4, 
                       on=["season","lg","team", "g"], 
                       how="left")
print("Join temp6_b and temp4:", temp6_c.count())

temp6 = temp6_c.join(temp5,
                     on=["season","lg", "team", "g"],
                     how="left")
print("Join temp6_c and temp5:", temp6.count())

# %%
temp7 = temp6.join(award_df_filtered,
                   on=["season","player", "player_id", "age"],
                   how="left")

# %%
temp7.show()
